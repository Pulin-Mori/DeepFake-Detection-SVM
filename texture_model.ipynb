# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("face_feature_texture values.csv")
data.describe()
# Out:
#        nose_mean_gradient  nose_variance_gradient  nose_skewness_gradient  \
# count        13311.000000            13311.000000            13311.000000
# mean             4.192802               40.035945                2.961433
# std              2.263393               43.157335                0.960747
# min              0.507544                0.203449                0.658328
# 25%              2.652418                8.123547                2.316775
# 50%              3.927606               24.514896                2.860809
# 75%              5.514755               55.631488                3.511291
# max             13.597747              278.582367               11.312214
#
#        nose_kurtosis_gradient  nose_std_dev_gray  nose_contrast_glcm  \
# count            13311.000000       13311.000000        13311.000000
# mean                13.237464          29.622018           55.866056
# std                 10.374347          17.074108           60.677648
# min                  0.243827           2.738912            0.591979
# 25%                  7.104876          18.187467           12.999712
# 50%                 10.969020          26.254693           35.777690
# 75%                 16.582379          37.323073           75.871281
# max                229.788059          96.449548          358.016484
#
#        nose_energy_glcm  nose_homogeneity_glcm  nose_entropy_glcm  \
# count      13311.000000           13311.000000       13311.000000
# mean           0.069727               0.437148          38.045128
# std            0.048886               0.126630           5.842815
# min            0.019015               0.192368          18.465803
# 25%            0.037514               0.342094          35.707947
# 50%            0.051115               0.415530          39.176931
# 75%            0.079356               0.504152          42.258175
# max            0.328980               0.814684          48.965551
#
#        nose_correlation_glcm  ...  mouth_left_mean_cH  mouth_left_std_dev_cH  \
# count           13311.000000  ...        13311.000000           13311.000000
# mean                0.970761  ...            0.147065              15.509884
# std                 0.020993  ...            1.222778               8.404761
# min                 0.832688  ...           -5.103600               1.294388
# 25%                 0.962735  ...           -0.453600               8.807999
# 50%                 0.976497  ...            0.205600              14.862184
# 75%                 0.985441  ...            0.806400              21.078473
# max                 0.998143  ...            4.580800              48.796129
#
#        mouth_left_energy_cH  mouth_left_mean_cV  mouth_left_std_dev_cV  \
# count          13311.000000        13311.000000           13311.000000
# mean             312.707903           -0.399238              15.050456
# std              310.369746            2.438743              10.400995
# min                1.678400           -8.962800               0.924480
# 25%               77.993300           -1.498400               6.606928
# 50%              222.181700           -0.360000              11.586527
# 75%              445.939100            0.880000              22.220496
# max             2382.662900            8.509600              67.483499
#
#        mouth_left_energy_cV  mouth_left_mean_cD  mouth_left_std_dev_cD  \
# count          13311.000000        13311.000000           13311.000000
# mean             340.795223           -0.002637               4.729389
# std              435.142062            0.077522               3.454661
# min                0.854700           -0.634800               0.374027
# 25%               45.204350           -0.037600               1.976128
# 50%              137.733600           -0.001200               3.552619
# 75%              501.347100            0.036000               6.851007
# max             4602.815700            0.533200              19.144660
#
#        mouth_left_energy_cD   frame_count
# count          13311.000000  13311.000000
# mean              34.306925    154.832845
# std               45.872531     86.479871
# min                0.139900     10.000000
# 25%                3.905800     80.000000
# 50%               12.621700    150.000000
# 75%               46.948300    230.000000
# max              366.544500    300.000000
#
# [8 rows x 96 columns]

# %%
data.isna().sum()
# Out:
# nose_mean_gradient        0
# nose_variance_gradient    0
# nose_skewness_gradient    0
# nose_kurtosis_gradient    0
# nose_std_dev_gray         0
#                          ..
# mouth_left_std_dev_cD     0
# mouth_left_energy_cD      0
# frame_count               0
# video_file                0
# label                     0
# Length: 98, dtype: int64

# %%
data.dropna(inplace=True)
data.head()
# Out:
#    nose_mean_gradient  nose_variance_gradient  nose_skewness_gradient  \
# 0            2.928087               14.158707                6.219130
# 1            2.456648                4.858655                2.192118
# 2            3.271335               17.673316                4.856371
# 3            3.128868               12.022511                4.459832
# 4            2.956477               15.838694                4.971668
#
#    nose_kurtosis_gradient  nose_std_dev_gray  nose_contrast_glcm  \
# 0               64.051817          23.989590           20.482117
# 1                6.375248          20.288418            9.311862
# 2               35.212752          21.775651           26.463631
# 3               34.806225          19.872416           19.938427
# 4               38.454684          17.742675           21.093719
#
#    nose_energy_glcm  nose_homogeneity_glcm  nose_entropy_glcm  \
# 0          0.047322               0.437409          39.056077
# 1          0.051928               0.455205          37.907665
# 2          0.046427               0.412656          39.041983
# 3          0.052240               0.405084          38.220256
# 4          0.058946               0.442142          36.753666
#
#    nose_correlation_glcm  ...  mouth_left_energy_cH  mouth_left_mean_cV  \
# 0               0.982001  ...              147.4660             -0.9248
# 1               0.988611  ...              150.9497             -0.6188
# 2               0.972127  ...              124.5235             -0.0788
# 3               0.974617  ...              103.0708             -1.1912
# 4               0.966222  ...               71.1569             -1.0036
#
#    mouth_left_std_dev_cV  mouth_left_energy_cV  mouth_left_mean_cD  \
# 0              22.660016              514.3316             -0.0344
# 1              20.254885              410.6433             -0.0700
# 2              16.300224              265.7035             -0.1284
# 3               7.746525               61.4276             -0.0472
# 4               5.064434               26.6557              0.0244
#
#    mouth_left_std_dev_cD  mouth_left_energy_cD  frame_count      video_file  \
# 0               3.720916               13.8464           10  aagfhgtpmv.mp4
# 1               3.377040               11.4093           20  aagfhgtpmv.mp4
# 2               4.925425               24.2763           30  aagfhgtpmv.mp4
# 3               2.610474                6.8168           40  aagfhgtpmv.mp4
# 4               2.206152                4.8677           50  aagfhgtpmv.mp4
#
#    label
# 0   FAKE
# 1   FAKE
# 2   FAKE
# 3   FAKE
# 4   FAKE
#
# [5 rows x 98 columns]

# %%
y = data["label"]
x = data.iloc[:,:-3]

encode = LabelEncoder()
y = encode.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
svm_model = SVC(kernel='linear')
svm_model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8084866691701089
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.94      0.89      2090
#            1       0.61      0.32      0.42       573
#
#     accuracy                           0.81      2663
#    macro avg       0.72      0.63      0.65      2663
# weighted avg       0.78      0.81      0.78      2663

# %%
import pickle

with open('svm_model(1).pkl', 'wb') as f:
    pickle.dump(svm_model, f)

print("Model successfully saved")
# Out:
# Model successfully saved
